# %%
from starkiller import sat_killer
import cv2
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
image = cv2.imread('thumb.png',0)

# %%
plt.figure()
plt.imshow(image,origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
sat = sat_killer(1,1,run=False)
sat.image = image
sat._set_threshold(3)
print(sat.threshold)
# Out:
# 153.32214860679605

# %%
sat._dilate()
sat._edges()
sat._lines()
sat._match_lines()
sat._find_center()
sat.make_mask()
sat._detected()

# %%
sat.plot_lines()
plt.savefig('thumbnail_test.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
